# %%
#install unidecode library to remove discrepant text characters
#while handling non-ASCII characters to translate from website to a pandas dataframe
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading Unidecode-1.3.8-py3-none-any.whl.metadata (13 kB)
# Downloading Unidecode-1.3.8-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 13.2 MB/s eta 0:00:00
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.8

# %%
#get useful libraries
import numpy as np
import pandas as pd
import random
import time
from unidecode import unidecode

# %%
#team dictionary corresponding to abbreviations in basketball-reference
teams = [
    'atl', 'bos', 'brk', 'cho', 'chi', 'cle', 'dal', 'den', 'det', 'gsw',
    'hou', 'ind', 'lac', 'lal', 'mem', 'mia', 'mil', 'min', 'nop', 'nyk',
    'okc', 'orl', 'phi', 'pho', 'por', 'sac', 'sas', 'tor', 'uta', 'was'
]
len(teams)
# Out:
# 30

# %%
#season dictionary to iterate through while web scraping
seasons = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']
len(seasons)
# Out:
# 9

# %%
#stats dictionary corresponding to those in basketball-reference
stats = [
    'FG', 'FGA', 'FG%',
    '3P', '3PA', '3P%',
    'FT', 'FTA', 'FT%',
    'ORB', 'TRB', 'AST',
    'STL', 'BLK', 'TOV', 'PF'
]

#split into corresponding team and opponent stats
tm_stats_dict = {stat: 'Tm_' + str(stat) for stat in stats}

opp_stats_dict = {stat + '.1': 'Opp_' + str(stat) for stat in stats}

# %%
#empty dataframe to hold the game logs
nba_df = pd.DataFrame()

#iterate through all teams for each season
for season in seasons:
    for team in teams:
      #url containing gamelog data for all teams/seasons
      url = 'https://www.basketball-reference.com/teams/' + team + '/' + season + '/gamelog/'
      print(url) #track progress

      #read html table having the gamelog
      team_df = pd.read_html(url, header=1, attrs={'id':'tgl_basic'})[0]

      #remove irrelevant rows and columns
      team_df = team_df[(team_df['Rk'].str != '') & (team_df['Rk'].str.isnumeric())]
      team_df = team_df.drop(columns=['Rk', 'Unnamed: 24'])

      #rename confusing columns for clarity
      team_df = team_df.rename(columns={'Unnamed: 3': 'Home', 'Tm':'Tm_Pts', 'Opp.1':'Opp_Pts'})
      team_df = team_df.rename(columns=tm_stats_dict)
      team_df = team_df.rename(columns=opp_stats_dict)

      #make the 'home' column binary (1 for home, 0 for away)
      team_df['Home'] = team_df['Home'].apply(lambda x: 0 if x == '@' else 1)

      #added season and team columns at beginning of dataframe
      team_df.insert(loc=0, column='Season', value=season)
      team_df.insert(loc=1, column='Team', value=team.upper())

      #add game logs to original main dataframe
      nba_df = pd.concat([nba_df, team_df], ignore_index=True)

      #time delay for processing purposes
      time.sleep(random.randint(4,6))

print(nba_df)
# Out:
# https://www.basketball-reference.com/teams/atl/2015/gamelog/
# https://www.basketball-reference.com/teams/bos/2015/gamelog/
# https://www.basketball-reference.com/teams/brk/2015/gamelog/
# https://www.basketball-reference.com/teams/cho/2015/gamelog/
# https://www.basketball-reference.com/teams/chi/2015/gamelog/
# https://www.basketball-reference.com/teams/cle/2015/gamelog/
# https://www.basketball-reference.com/teams/dal/2015/gamelog/
# https://www.basketball-reference.com/teams/den/2015/gamelog/
# https://www.basketball-reference.com/teams/det/2015/gamelog/
# https://www.basketball-reference.com/teams/gsw/2015/gamelog/
# https://www.basketball-reference.com/teams/hou/2015/gamelog/
# https://www.basketball-reference.com/teams/ind/2015/gamelog/
# https://www.basketball-reference.com/teams/lac/2015/gamelog/
# https://www.basketball-reference.com/teams/lal/2015/gamelog/
# https://www.basketball-reference.com/teams/mem/2015/gamelog/
# https://www.basketball-reference.com/teams/mia/2015/gamelog/
# https://www.basketball-reference.com/teams/mil/2015/gamelog/
# https://www.basketball-reference.com/teams/min/2015/gamelog/
# https://www.basketball-reference.com/teams/nop/2015/gamelog/
# https://www.basketball-reference.com/teams/nyk/2015/gamelog/
# https://www.basketball-reference.com/teams/okc/2015/gamelog/
# https://www.basketball-reference.com/teams/orl/2015/gamelog/
# https://www.basketball-reference.com/teams/phi/2015/gamelog/
# https://www.basketball-reference.com/teams/pho/2015/gamelog/
# https://www.basketball-reference.com/teams/por/2015/gamelog/
# https://www.basketball-reference.com/teams/sac/2015/gamelog/
# https://www.basketball-reference.com/teams/sas/2015/gamelog/
# https://www.basketball-reference.com/teams/tor/2015/gamelog/
# https://www.basketball-reference.com/teams/uta/2015/gamelog/
# https://www.basketball-reference.com/teams/was/2015/gamelog/
# https://www.basketball-reference.com/teams/atl/2016/gamelog/
# https://www.basketball-reference.com/teams/bos/2016/gamelog/
# https://www.basketball-reference.com/teams/brk/2016/gamelog/
# https://www.basketball-reference.com/teams/cho/2016/gamelog/
# https://www.basketball-reference.com/teams/chi/2016/gamelog/
# https://www.basketball-reference.com/teams/cle/2016/gamelog/
# https://www.basketball-reference.com/teams/dal/2016/gamelog/
# https://www.basketball-reference.com/teams/den/2016/gamelog/
# https://www.basketball-reference.com/teams/det/2016/gamelog/
# https://www.basketball-reference.com/teams/gsw/2016/gamelog/
# https://www.basketball-reference.com/teams/hou/2016/gamelog/
# https://www.basketball-reference.com/teams/ind/2016/gamelog/
# https://www.basketball-reference.com/teams/lac/2016/gamelog/
# https://www.basketball-reference.com/teams/lal/2016/gamelog/
# https://www.basketball-reference.com/teams/mem/2016/gamelog/
# https://www.basketball-reference.com/teams/mia/2016/gamelog/
# https://www.basketball-reference.com/teams/mil/2016/gamelog/
# https://www.basketball-reference.com/teams/min/2016/gamelog/
# https://www.basketball-reference.com/teams/nop/2016/gamelog/
# https://www.basketball-reference.com/teams/nyk/2016/gamelog/
# https://www.basketball-reference.com/teams/okc/2016/gamelog/
# https://www.basketball-reference.com/teams/orl/2016/gamelog/
# https://www.basketball-reference.com/teams/phi/2016/gamelog/
# https://www.basketball-reference.com/teams/pho/2016/gamelog/
# https://www.basketball-reference.com/teams/por/2016/gamelog/
# https://www.basketball-reference.com/teams/sac/2016/gamelog/
# https://www.basketball-reference.com/teams/sas/2016/gamelog/
# https://www.basketball-reference.com/teams/tor/2016/gamelog/
# https://www.basketball-reference.com/teams/uta/2016/gamelog/
# https://www.basketball-reference.com/teams/was/2016/gamelog/
# https://www.basketball-reference.com/teams/atl/2017/gamelog/
# https://www.basketball-reference.com/teams/bos/2017/gamelog/
# https://www.basketball-reference.com/teams/brk/2017/gamelog/
# https://www.basketball-reference.com/teams/cho/2017/gamelog/
# https://www.basketball-reference.com/teams/chi/2017/gamelog/
# https://www.basketball-reference.com/teams/cle/2017/gamelog/
# https://www.basketball-reference.com/teams/dal/2017/gamelog/
# https://www.basketball-reference.com/teams/den/2017/gamelog/
# https://www.basketball-reference.com/teams/det/2017/gamelog/
# https://www.basketball-reference.com/teams/gsw/2017/gamelog/
# https://www.basketball-reference.com/teams/hou/2017/gamelog/
# https://www.basketball-reference.com/teams/ind/2017/gamelog/
# https://www.basketball-reference.com/teams/lac/2017/gamelog/
# https://www.basketball-reference.com/teams/lal/2017/gamelog/
# https://www.basketball-reference.com/teams/mem/2017/gamelog/
# https://www.basketball-reference.com/teams/mia/2017/gamelog/
# https://www.basketball-reference.com/teams/mil/2017/gamelog/
# https://www.basketball-reference.com/teams/min/2017/gamelog/
# https://www.basketball-reference.com/teams/nop/2017/gamelog/
# https://www.basketball-reference.com/teams/nyk/2017/gamelog/
# https://www.basketball-reference.com/teams/okc/2017/gamelog/
# https://www.basketball-reference.com/teams/orl/2017/gamelog/
# https://www.basketball-reference.com/teams/phi/2017/gamelog/
# https://www.basketball-reference.com/teams/pho/2017/gamelog/
# https://www.basketball-reference.com/teams/por/2017/gamelog/
# https://www.basketball-reference.com/teams/sac/2017/gamelog/
# https://www.basketball-reference.com/teams/sas/2017/gamelog/
# https://www.basketball-reference.com/teams/tor/2017/gamelog/
# https://www.basketball-reference.com/teams/uta/2017/gamelog/
# https://www.basketball-reference.com/teams/was/2017/gamelog/
# https://www.basketball-reference.com/teams/atl/2018/gamelog/
# https://www.basketball-reference.com/teams/bos/2018/gamelog/
# https://www.basketball-reference.com/teams/brk/2018/gamelog/
# https://www.basketball-reference.com/teams/cho/2018/gamelog/
# https://www.basketball-reference.com/teams/chi/2018/gamelog/
# https://www.basketball-reference.com/teams/cle/2018/gamelog/
# https://www.basketball-reference.com/teams/dal/2018/gamelog/
# https://www.basketball-reference.com/teams/den/2018/gamelog/
# https://www.basketball-reference.com/teams/det/2018/gamelog/
# https://www.basketball-reference.com/teams/gsw/2018/gamelog/
# https://www.basketball-reference.com/teams/hou/2018/gamelog/
# https://www.basketball-reference.com/teams/ind/2018/gamelog/
# https://www.basketball-reference.com/teams/lac/2018/gamelog/
# https://www.basketball-reference.com/teams/lal/2018/gamelog/
# https://www.basketball-reference.com/teams/mem/2018/gamelog/
# https://www.basketball-reference.com/teams/mia/2018/gamelog/
# https://www.basketball-reference.com/teams/mil/2018/gamelog/
# https://www.basketball-reference.com/teams/min/2018/gamelog/
# https://www.basketball-reference.com/teams/nop/2018/gamelog/
# https://www.basketball-reference.com/teams/nyk/2018/gamelog/
# https://www.basketball-reference.com/teams/okc/2018/gamelog/
# https://www.basketball-reference.com/teams/orl/2018/gamelog/
# https://www.basketball-reference.com/teams/phi/2018/gamelog/
# https://www.basketball-reference.com/teams/pho/2018/gamelog/
# https://www.basketball-reference.com/teams/por/2018/gamelog/
# https://www.basketball-reference.com/teams/sac/2018/gamelog/
# https://www.basketball-reference.com/teams/sas/2018/gamelog/
# https://www.basketball-reference.com/teams/tor/2018/gamelog/
# https://www.basketball-reference.com/teams/uta/2018/gamelog/
# https://www.basketball-reference.com/teams/was/2018/gamelog/
# https://www.basketball-reference.com/teams/atl/2019/gamelog/
# https://www.basketball-reference.com/teams/bos/2019/gamelog/
# https://www.basketball-reference.com/teams/brk/2019/gamelog/
# https://www.basketball-reference.com/teams/cho/2019/gamelog/
# https://www.basketball-reference.com/teams/chi/2019/gamelog/
# https://www.basketball-reference.com/teams/cle/2019/gamelog/
# https://www.basketball-reference.com/teams/dal/2019/gamelog/
# https://www.basketball-reference.com/teams/den/2019/gamelog/
# https://www.basketball-reference.com/teams/det/2019/gamelog/
# https://www.basketball-reference.com/teams/gsw/2019/gamelog/
# https://www.basketball-reference.com/teams/hou/2019/gamelog/
# https://www.basketball-reference.com/teams/ind/2019/gamelog/
# https://www.basketball-reference.com/teams/lac/2019/gamelog/
# https://www.basketball-reference.com/teams/lal/2019/gamelog/
# https://www.basketball-reference.com/teams/mem/2019/gamelog/
# https://www.basketball-reference.com/teams/mia/2019/gamelog/
# https://www.basketball-reference.com/teams/mil/2019/gamelog/
# https://www.basketball-reference.com/teams/min/2019/gamelog/
# https://www.basketball-reference.com/teams/nop/2019/gamelog/
# https://www.basketball-reference.com/teams/nyk/2019/gamelog/
# https://www.basketball-reference.com/teams/okc/2019/gamelog/
# https://www.basketball-reference.com/teams/orl/2019/gamelog/
# https://www.basketball-reference.com/teams/phi/2019/gamelog/
# https://www.basketball-reference.com/teams/pho/2019/gamelog/
# https://www.basketball-reference.com/teams/por/2019/gamelog/
# https://www.basketball-reference.com/teams/sac/2019/gamelog/
# https://www.basketball-reference.com/teams/sas/2019/gamelog/
# https://www.basketball-reference.com/teams/tor/2019/gamelog/
# https://www.basketball-reference.com/teams/uta/2019/gamelog/
# https://www.basketball-reference.com/teams/was/2019/gamelog/
# https://www.basketball-reference.com/teams/atl/2020/gamelog/
# https://www.basketball-reference.com/teams/bos/2020/gamelog/
# https://www.basketball-reference.com/teams/brk/2020/gamelog/
# https://www.basketball-reference.com/teams/cho/2020/gamelog/
# https://www.basketball-reference.com/teams/chi/2020/gamelog/
# https://www.basketball-reference.com/teams/cle/2020/gamelog/
# https://www.basketball-reference.com/teams/dal/2020/gamelog/
# https://www.basketball-reference.com/teams/den/2020/gamelog/
# https://www.basketball-reference.com/teams/det/2020/gamelog/
# https://www.basketball-reference.com/teams/gsw/2020/gamelog/
# https://www.basketball-reference.com/teams/hou/2020/gamelog/
# https://www.basketball-reference.com/teams/ind/2020/gamelog/
# https://www.basketball-reference.com/teams/lac/2020/gamelog/
# https://www.basketball-reference.com/teams/lal/2020/gamelog/
# https://www.basketball-reference.com/teams/mem/2020/gamelog/
# https://www.basketball-reference.com/teams/mia/2020/gamelog/
# https://www.basketball-reference.com/teams/mil/2020/gamelog/
# https://www.basketball-reference.com/teams/min/2020/gamelog/
# https://www.basketball-reference.com/teams/nop/2020/gamelog/
# https://www.basketball-reference.com/teams/nyk/2020/gamelog/
# https://www.basketball-reference.com/teams/okc/2020/gamelog/
# https://www.basketball-reference.com/teams/orl/2020/gamelog/
# https://www.basketball-reference.com/teams/phi/2020/gamelog/
# https://www.basketball-reference.com/teams/pho/2020/gamelog/
# https://www.basketball-reference.com/teams/por/2020/gamelog/
# https://www.basketball-reference.com/teams/sac/2020/gamelog/
# https://www.basketball-reference.com/teams/sas/2020/gamelog/
# https://www.basketball-reference.com/teams/tor/2020/gamelog/
# https://www.basketball-reference.com/teams/uta/2020/gamelog/
# https://www.basketball-reference.com/teams/was/2020/gamelog/
# https://www.basketball-reference.com/teams/atl/2021/gamelog/
# https://www.basketball-reference.com/teams/bos/2021/gamelog/
# https://www.basketball-reference.com/teams/brk/2021/gamelog/
# https://www.basketball-reference.com/teams/cho/2021/gamelog/
# https://www.basketball-reference.com/teams/chi/2021/gamelog/
# https://www.basketball-reference.com/teams/cle/2021/gamelog/
# https://www.basketball-reference.com/teams/dal/2021/gamelog/
# https://www.basketball-reference.com/teams/den/2021/gamelog/
# https://www.basketball-reference.com/teams/det/2021/gamelog/
# https://www.basketball-reference.com/teams/gsw/2021/gamelog/
# https://www.basketball-reference.com/teams/hou/2021/gamelog/
# https://www.basketball-reference.com/teams/ind/2021/gamelog/
# https://www.basketball-reference.com/teams/lac/2021/gamelog/
# https://www.basketball-reference.com/teams/lal/2021/gamelog/
# https://www.basketball-reference.com/teams/mem/2021/gamelog/
# https://www.basketball-reference.com/teams/mia/2021/gamelog/
# https://www.basketball-reference.com/teams/mil/2021/gamelog/
# https://www.basketball-reference.com/teams/min/2021/gamelog/
# https://www.basketball-reference.com/teams/nop/2021/gamelog/
# https://www.basketball-reference.com/teams/nyk/2021/gamelog/
# https://www.basketball-reference.com/teams/okc/2021/gamelog/
# https://www.basketball-reference.com/teams/orl/2021/gamelog/
# https://www.basketball-reference.com/teams/phi/2021/gamelog/
# https://www.basketball-reference.com/teams/pho/2021/gamelog/
# https://www.basketball-reference.com/teams/por/2021/gamelog/
# https://www.basketball-reference.com/teams/sac/2021/gamelog/
# https://www.basketball-reference.com/teams/sas/2021/gamelog/
# https://www.basketball-reference.com/teams/tor/2021/gamelog/
# https://www.basketball-reference.com/teams/uta/2021/gamelog/
# https://www.basketball-reference.com/teams/was/2021/gamelog/
# https://www.basketball-reference.com/teams/atl/2022/gamelog/
# https://www.basketball-reference.com/teams/bos/2022/gamelog/
# https://www.basketball-reference.com/teams/brk/2022/gamelog/
# https://www.basketball-reference.com/teams/cho/2022/gamelog/
# https://www.basketball-reference.com/teams/chi/2022/gamelog/
# https://www.basketball-reference.com/teams/cle/2022/gamelog/
# https://www.basketball-reference.com/teams/dal/2022/gamelog/
# https://www.basketball-reference.com/teams/den/2022/gamelog/
# https://www.basketball-reference.com/teams/det/2022/gamelog/
# https://www.basketball-reference.com/teams/gsw/2022/gamelog/
# https://www.basketball-reference.com/teams/hou/2022/gamelog/
# https://www.basketball-reference.com/teams/ind/2022/gamelog/
# https://www.basketball-reference.com/teams/lac/2022/gamelog/
# https://www.basketball-reference.com/teams/lal/2022/gamelog/
# https://www.basketball-reference.com/teams/mem/2022/gamelog/
# https://www.basketball-reference.com/teams/mia/2022/gamelog/
# https://www.basketball-reference.com/teams/mil/2022/gamelog/
# https://www.basketball-reference.com/teams/min/2022/gamelog/
# https://www.basketball-reference.com/teams/nop/2022/gamelog/
# https://www.basketball-reference.com/teams/nyk/2022/gamelog/
# https://www.basketball-reference.com/teams/okc/2022/gamelog/
# https://www.basketball-reference.com/teams/orl/2022/gamelog/
# https://www.basketball-reference.com/teams/phi/2022/gamelog/
# https://www.basketball-reference.com/teams/pho/2022/gamelog/
# https://www.basketball-reference.com/teams/por/2022/gamelog/
# https://www.basketball-reference.com/teams/sac/2022/gamelog/
# https://www.basketball-reference.com/teams/sas/2022/gamelog/
# https://www.basketball-reference.com/teams/tor/2022/gamelog/
# https://www.basketball-reference.com/teams/uta/2022/gamelog/
# https://www.basketball-reference.com/teams/was/2022/gamelog/
# https://www.basketball-reference.com/teams/atl/2023/gamelog/
# https://www.basketball-reference.com/teams/bos/2023/gamelog/
# https://www.basketball-reference.com/teams/brk/2023/gamelog/
# https://www.basketball-reference.com/teams/cho/2023/gamelog/
# https://www.basketball-reference.com/teams/chi/2023/gamelog/
# https://www.basketball-reference.com/teams/cle/2023/gamelog/
# https://www.basketball-reference.com/teams/dal/2023/gamelog/
# https://www.basketball-reference.com/teams/den/2023/gamelog/
# https://www.basketball-reference.com/teams/det/2023/gamelog/
# https://www.basketball-reference.com/teams/gsw/2023/gamelog/
# https://www.basketball-reference.com/teams/hou/2023/gamelog/
# https://www.basketball-reference.com/teams/ind/2023/gamelog/
# https://www.basketball-reference.com/teams/lac/2023/gamelog/
# https://www.basketball-reference.com/teams/lal/2023/gamelog/
# https://www.basketball-reference.com/teams/mem/2023/gamelog/
# https://www.basketball-reference.com/teams/mia/2023/gamelog/
# https://www.basketball-reference.com/teams/mil/2023/gamelog/
# https://www.basketball-reference.com/teams/min/2023/gamelog/
# https://www.basketball-reference.com/teams/nop/2023/gamelog/
# https://www.basketball-reference.com/teams/nyk/2023/gamelog/
# https://www.basketball-reference.com/teams/okc/2023/gamelog/
# https://www.basketball-reference.com/teams/orl/2023/gamelog/
# https://www.basketball-reference.com/teams/phi/2023/gamelog/
# https://www.basketball-reference.com/teams/pho/2023/gamelog/
# https://www.basketball-reference.com/teams/por/2023/gamelog/
# https://www.basketball-reference.com/teams/sac/2023/gamelog/
# https://www.basketball-reference.com/teams/sas/2023/gamelog/
# https://www.basketball-reference.com/teams/tor/2023/gamelog/
# https://www.basketball-reference.com/teams/uta/2023/gamelog/
# https://www.basketball-reference.com/teams/was/2023/gamelog/
#       Season Team   G        Date  Home  Opp W/L Tm_Pts Opp_Pts Tm_FG  ...  \
# 0       2015  ATL   1  2014-10-29     0  TOR   L    102     109    40  ...
# 1       2015  ATL   2  2014-11-01     1  IND   W    102      92    35  ...
# 2       2015  ATL   3  2014-11-05     0  SAS   L     92      94    38  ...
# 3       2015  ATL   4  2014-11-07     0  CHO   L    119     122    43  ...
# 4       2015  ATL   5  2014-11-08     1  NYK   W    103      96    33  ...
# ...      ...  ...  ..         ...   ...  ...  ..    ...     ...   ...  ...
# 21493   2023  WAS  78  2023-04-02     0  NYK   L    109     118    39  ...
# 21494   2023  WAS  79  2023-04-04     1  MIL   L    128     140    50  ...
# 21495   2023  WAS  80  2023-04-05     0  ATL   L    116     134    45  ...
# 21496   2023  WAS  81  2023-04-07     1  MIA   W    114     108    39  ...
# 21497   2023  WAS  82  2023-04-09     1  HOU   L    109     114    41  ...
#
#       Opp_FT Opp_FTA Opp_FT% Opp_ORB Opp_TRB Opp_AST Opp_STL Opp_BLK Opp_TOV  \
# 0         27      33    .818      16      48      26      13       9      10
# 1         18      21    .857      11      44      25       5       5      18
# 2         27      38    .711      11      50      25       7       9      21
# 3         20      27    .741      11      51      31       6       7      21
# 4          8      11    .727      13      44      26       2       6      15
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 21493     13      18    .722       7      39      31      12       4      12
# 21494     17      29    .586      12      56      33       6       7      18
# 21495     35      40    .875      12      48      30      10       5      17
# 21496      7      12    .583      14      47      26       7       4      16
# 21497     20      28    .714      13      51      24       8       6      15
#
#       Opp_PF
# 0         22
# 1         26
# 2         15
# 3         30
# 4         29
# ...      ...
# 21493     17
# 21494     19
# 21495     23
# 21496     29
# 21497     15
#
# [21498 rows x 41 columns]

# %%
#save dataframe to csv file
nba_df.to_csv('nbaGamelogs.csv', index=False)
